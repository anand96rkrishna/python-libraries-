# %% [markdown]
# **Seaborn** is an open source, Python library for visualizing the data using Python programming language.

# %% [markdown]
# **Importing Datasets**
#
# Seaborn comes with a few important datasets in the library. When Seaborn is installed, the datasets download automatically.
#
# You can use any of these datasets for your learning. With the help of the following function you can load the required dataset
#
# **load_dataset() **

# %%
import seaborn as sb
df = sb.load_dataset('tips')
df
#tip is independent feature
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Dinner', 'Lunch']

# %%
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df[0:1]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
#use get method to get all the names of datasets
import seaborn as sb
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %% [markdown]
# if we are considering only 1 variable it is called **UNIVARIATE ANALYSIS**
# If we are considering 2 variables it is called **BIVARIATE ANALYSIS**
# Both can be easily done by seaborn
# seaborn helps us  with **MULTIVARIATE ANALYSIS**
#
#
#
# **Distribution plots** all are continuous plots
#
# distplot
#
# joinplot-bivariate analysis
#
# pairplot-more than 2 features

# %% [markdown]
# **CORRELATION** **HEATMAP**
#
# Finds out the inter relation between features
#
#  we find correlation heatmap only  when all features are **INTEGER OR FLOATING**
#
#  values -1 to +1

# %%
a = 5
s = str(a)
type(s)
# Out:
# str

# %%
df.corr() #here rest all columns are categorical
#total bill and total bill correlation is 1 
#total bill and tip corr is.67.. means  when bill increases tip  will also increase
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
sb.heatmap(df.corr())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5bf5719ea17b> in <module>()
# ----> 1 sb.heatmap(df.corr())
#
# NameError: name 'sb' is not defined

# %% [markdown]
# **JOINT PLOT**
# A join plot allows to study the relationship between 2 numeric variables.

# %%
sb.jointplot(x='tip',y='total_bill',data=df)

# %%
sb.jointplot(x='tip',y='total_bill',data=df,kind ='reg')#we change the kind parameter
#curve over histogram is PDF
#Line is the best fit line

# %% [markdown]
# **PAIR PLOT**
#
# more than two independent features
#
# features need to be either integer or a float

# %%
sb.pairplot(df) # it will take only the numeric values

# %%
sb.pairplot(df,hue='day')#if we want to add a categorical value in pairplot

# %%
#value counts
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %% [markdown]
# **DIST PLOT**
# gives the histogram

# %%
sb.distplot(df['tip'])

# %% [markdown]
# **Categorical Plots**
#
# Seaborn also helps us in doing the analysis on Categorical Data points.
#
# boxplot
# violinplot
# countplot
# bar plot

# %%
#count plot
sb.countplot('sex',data=df)
#we get count of male and female

# %%
sb.countplot('day',data=df)

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
#by default values are shown in x axis
#we can also change axis
sb.countplot(y='day',data=df)

# %%
#BAR PLOT
#same as count plot but we need to specify x and y values
## Bar plot
## Bar plot
sb.barplot(x='sex',y='total_bill',data=df)

# %%
#Violin plot 
#helps us to see both the distribution of data in terms of Kernel density estimation and the box plot
sb.violinplot(x="total_bill", y="day", data=df,palette='rainbow')
